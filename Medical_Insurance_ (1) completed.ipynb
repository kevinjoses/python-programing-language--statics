# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Medical_insurance (1).csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df.shape
# Out:
# (2772, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1435)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   50    male  30.970         3     no  northwest  10600.54830
# 1333   18  female  31.920         0     no  northeast   2205.98080
# 1334   18  female  36.850         0     no  southeast   1629.83350
# 1335   21  female  25.800         0     no  southwest   2007.94500
# 1336   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df['age'].value_counts()
# Out:
# age
# 18    69
# 19    67
# 46    29
# 52    29
# 50    29
# 47    29
# 48    29
# 51    29
# 45    29
# 20    29
# 24    28
# 27    28
# 28    28
# 25    28
# 23    28
# 49    28
# 54    28
# 53    28
# 22    28
# 21    28
# 26    28
# 31    27
# 41    27
# 44    27
# 43    27
# 42    27
# 29    27
# 30    27
# 40    27
# 32    26
# 33    26
# 57    26
# 34    26
# 55    26
# 56    26
# 35    25
# 58    25
# 37    25
# 59    25
# 39    25
# 36    25
# 38    25
# 62    23
# 60    23
# 63    23
# 61    23
# 64    22
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x=df["age"])
plt.title("Medical insurance")
plt.show
print(df["age"].describe())
# Out:
# count    1337.000000
# mean       39.222139
# std        14.044333
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
sns.kdeplot(df["age"],shade=True)
plt.title("KDE plot of Medical insurance")
plt.show
# Out:
# <ipython-input-17-51a7a942b54b>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["age"],shade=True)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(df["bmi"],bins=20,kde=True)
plt.title("bmi vs charges")
plt.show
print(df["bmi"].describe())
# Out:
# count    1337.000000
# mean       30.663452
# std         6.100468
# min        15.960000
# 25%        26.290000
# 50%        30.400000
# 75%        34.700000
# max        53.130000
# Name: bmi, dtype: float64

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   50    male  30.970         3     no  northwest  10600.54830
# 1333   18  female  31.920         0     no  northeast   2205.98080
# 1334   18  female  36.850         0     no  southeast   1629.83350
# 1335   21  female  25.800         0     no  southwest   2007.94500
# 1336   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
sns.histplot(df["children"],bins=20,kde=True)
plt.title("children vs charges")
plt.show
print(df["children"].describe())
# Out:
# count    1337.000000
# mean        1.095737
# std         1.205571
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
sns.histplot(df["charges"],bins=20,kde=True)
plt.title("charges vs charges")
plt.show
print(df["charges"].describe())
# Out:
# count     1337.000000
# mean     13279.121487
# std      12110.359656
# min       1121.873900
# 25%       4746.344000
# 50%       9386.161300
# 75%      16657.717450
# max      63770.428010
# Name: charges, dtype: float64

# %% [markdown]
# UNIVARIATE CATAGORICAL

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df['sex'])
plt.xticks(rotation=40)
plt.title("sex")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df['smoker'])
plt.xticks(rotation=40)
plt.title("smoker")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df['region'])
plt.xticks(rotation=40)
plt.title("region")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['region']=lb.fit_transform(df['region'])
print(lb.classes_)
# Out:
# ['northeast' 'northwest' 'southeast' 'southwest']

# %%
df
# Out:
#       age     sex     bmi  children smoker  region      charges
# 0      19  female  27.900         0    yes       3  16884.92400
# 1      18    male  33.770         1     no       2   1725.55230
# 2      28    male  33.000         3     no       2   4449.46200
# 3      33    male  22.705         0     no       1  21984.47061
# 4      32    male  28.880         0     no       1   3866.85520
# ...   ...     ...     ...       ...    ...     ...          ...
# 1332   50    male  30.970         3     no       1  10600.54830
# 1333   18  female  31.920         0     no       0   2205.98080
# 1334   18  female  36.850         0     no       2   1629.83350
# 1335   21  female  25.800         0     no       3   2007.94500
# 1336   61  female  29.070         0    yes       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['sex']=lb.fit_transform(df['sex'])
print(lb.classes_)
# Out:
# ['female' 'male']

# %%
df
# Out:
#       age  sex     bmi  children smoker  region      charges
# 0      19    0  27.900         0    yes       3  16884.92400
# 1      18    1  33.770         1     no       2   1725.55230
# 2      28    1  33.000         3     no       2   4449.46200
# 3      33    1  22.705         0     no       1  21984.47061
# 4      32    1  28.880         0     no       1   3866.85520
# ...   ...  ...     ...       ...    ...     ...          ...
# 1332   50    1  30.970         3     no       1  10600.54830
# 1333   18    0  31.920         0     no       0   2205.98080
# 1334   18    0  36.850         0     no       2   1629.83350
# 1335   21    0  25.800         0     no       3   2007.94500
# 1336   61    0  29.070         0    yes       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['smoker']=lb.fit_transform(df['smoker'])
print(lb.classes_)
# Out:
# ['no' 'yes']

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1332   50    1  30.970         3       0       1  10600.54830
# 1333   18    0  31.920         0       0       0   2205.98080
# 1334   18    0  36.850         0       0       2   1629.83350
# 1335   21    0  25.800         0       0       3   2007.94500
# 1336   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
sns.boxplot(df["age"])
plt.title("age")
plt.show()

# %%
sns.boxplot(df["bmi"])
plt.title("bmi")
plt.show()

# %%
Q1=df['bmi'].quantile(0.25)
Q3=df['bmi'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['bmi']=np.where(df['bmi']>Maximum,Maximum,np.where(df['bmi']<Minimum,Minimum,df['bmi']))

# %%
sns.boxplot(df["bmi"])
plt.title("bmi")
plt.show()

# %%
sns.boxplot(df["charges"])
plt.title("charges")
plt.show()

# %%
Q1=df['charges'].quantile(0.25)
Q3=df['charges'].quantile(0.75)
IQR=Q3-Q1

Minimum=Q1-1.5*IQR
Maximum=Q3+1.5*IQR

df['charges']=np.where(df['charges']>Maximum,Maximum,np.where(df['charges']<Minimum,Minimum,df['charges']))

# %%
sns.boxplot(df["charges"])
plt.title("charges")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm",linewidths=0.5)
plt.title("correlation Heatmap")
plt.show()

# %%
df=df[["age","bmi","smoker"]]

# %%
df
# Out:
#       age     bmi  smoker
# 0      19  27.900       1
# 1      18  33.770       0
# 2      28  33.000       0
# 3      33  22.705       0
# 4      32  28.880       0
# ...   ...     ...     ...
# 1332   50  30.970       0
# 1333   18  31.920       0
# 1334   18  36.850       0
# 1335   21  25.800       0
# 1336   61  29.070       1
#
# [1337 rows x 3 columns]
