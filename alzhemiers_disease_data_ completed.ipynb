# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/alzheimers_disease_data (1) (1).csv')
pd.set_option('display.max_columns',40)
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0           13.297218          6.327112     1.347214      9.025679
# 1            4.542524          7.619885     0.518767      7.151293
# 2           19.555085          7.844988     1.826335      9.673574
# 3           12.209266          8.428001     7.435604      8.392554
# 4           18.454356          6.310461     0.795498      5.597238
#
#    FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  Depression  \
# ...

# %%
df.tail()
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 2144            1.561126          4.049964     6.555306      7.535540
# 2145           18.767261          1.360667     2.904662      8.555256
# 2146            4.594670          9.886002     8.120025      5.769464
# 2147            8.674505          6.354282     1.263427      8.322874
# 2148            7.890703          6.570993     7.941404      9.878711
#
#       FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  Depression  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
df.shape
# Out:
# (2149, 35)

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
df.isnull().sum()
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
df.drop(columns=['PatientID'],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
# df.drop(columns=['DoctorInCharge'],inplace=True)

# %%
# df.reset_index(inplace=True)

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
df=df.drop("DoctorInCharge",axis=1)

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['Age'])
plt.show()
print(df['Age'].describe())
# Out:
# count    2149.000000
# mean       74.908795
# std         8.990221
# min        60.000000
# 25%        67.000000
# 50%        75.000000
# 75%        83.000000
# max        90.000000
# Name: Age, dtype: float64

# %%
sns.kdeplot(df['Age'])
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['Gender'],bins=20,kde=True)
plt.title("Gender vs Diagnosis")
plt.show()
print(df['Gender'].describe())
# Out:
# count    2149.000000
# mean        0.506282
# std         0.500077
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Gender, dtype: float64

# %%
sns.histplot(df['Ethnicity'])
plt.title("Ethnicity vs Diagnosis")
plt.show()
print(df['Ethnicity'].describe())
# Out:
# count    2149.000000
# mean        0.697534
# std         0.996128
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Ethnicity, dtype: float64

# %%
sns.histplot(df['EducationLevel'])
plt.title("EducationLevel vs Diagnosis")
plt.show()
print(df['EducationLevel'].describe())
# Out:
# count    2149.000000
# mean        1.286645
# std         0.904527
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: EducationLevel, dtype: float64

# %%
sns.histplot(df['BMI'])
plt.title("BMI vs Diagnosis")
plt.show()
print(df['BMI'].describe())
# Out:
# count    2149.000000
# mean       27.655697
# std         7.217438
# min        15.008851
# 25%        21.611408
# 50%        27.823924
# 75%        33.869778
# max        39.992767
# Name: BMI, dtype: float64

# %%
sns.histplot(df['Smoking'])
plt.title("Smoking vs Diagnosis")
plt.show()
print(df['Smoking'].describe())
# Out:
# count    2149.000000
# mean        0.288506
# std         0.453173
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Smoking, dtype: float64

# %%
sns.histplot(df['AlcoholConsumption'])
plt.title("AlcoholConsumption vs Diagnosis")
plt.show()
print(df['AlcoholConsumption'].describe())
# Out:
# count    2149.000000
# mean       10.039442
# std         5.757910
# min         0.002003
# 25%         5.139810
# 50%         9.934412
# 75%        15.157931
# max        19.989293
# Name: AlcoholConsumption, dtype: float64

# %%
sns.histplot(df['PhysicalActivity'])
plt.title("PhysicalActivity vs Diagnosis")
plt.show()
print(df['PhysicalActivity'].describe())
# Out:
# count    2149.000000
# mean        4.920202
# std         2.857191
# min         0.003616
# 25%         2.570626
# 50%         4.766424
# 75%         7.427899
# max         9.987429
# Name: PhysicalActivity, dtype: float64

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
sns.histplot(df['PhysicalActivity'])
plt.title("PhysicalActivity	 vs Diagnosis")
plt.show()
print(df['PhysicalActivity'].describe())
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# count    2149.000000
# mean        4.920202
# std         2.857191
# min         0.003616
# 25%         2.570626
# 50%         4.766424
# 75%         7.427899
# max         9.987429
# Name: PhysicalActivity, dtype: float64

# %%
sns.histplot(df['DietQuality'])
plt.title("DietQuality vs Diagnosis")
plt.show()
print(df['DietQuality'].describe())
# Out:
# count    2149.000000
# mean        4.993138
# std         2.909055
# min         0.009385
# 25%         2.458455
# 50%         5.076087
# 75%         7.558625
# max         9.998346
# Name: DietQuality, dtype: float64

# %%
sns.histplot(df['SleepQuality'])
plt.title("SleepQuality vs Diagnosis")
plt.show()
print(df['SleepQuality'].describe())
# Out:
# count    2149.000000
# mean        7.051081
# std         1.763573
# min         4.002629
# 25%         5.482997
# 50%         7.115646
# 75%         8.562521
# max         9.999840
# Name: SleepQuality, dtype: float64

# %%
sns.histplot(df['FamilyHistoryAlzheimers'])
plt.title("FamilyHistoryAlzheimers vs Diagnosis")
plt.show()
print(df['FamilyHistoryAlzheimers'].describe())
# Out:
# count    2149.000000
# mean        0.252210
# std         0.434382
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: FamilyHistoryAlzheimers, dtype: float64

# %%
sns.histplot(df['CardiovascularDisease'])
plt.title("CardiovascularDisease vs Diagnosis")
plt.show()
print(df['CardiovascularDisease'].describe())
# Out:
# count    2149.000000
# mean        0.144253
# std         0.351428
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: CardiovascularDisease, dtype: float64

# %%
sns.histplot(df['Diabetes'])
plt.title("Diabetes vs Diagnosis")
plt.show()
print(df['Diabetes'].describe())
# Out:
# count    2149.000000
# mean        0.150768
# std         0.357906
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Diabetes, dtype: float64

# %%
sns.histplot(df['Depression'])
plt.title("Depression vs Diagnosis")
plt.show()
print(df['Depression'].describe())
# Out:
# count    2149.000000
# mean        0.200558
# std         0.400511
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Depression, dtype: float64

# %%
sns.histplot(df['HeadInjury'])
plt.title("HeadInjury vs Diagnosis")
plt.show()
print(df['HeadInjury'].describe())
# Out:
# count    2149.000000
# mean        0.092601
# std         0.289940
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: HeadInjury, dtype: float64

# %%
sns.histplot(df['Hypertension'])
plt.title("Hypertension vs Diagnosis")
plt.show()
print(df['Hypertension'].describe())
# Out:
# count    2149.000000
# mean        0.148906
# std         0.356079
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Hypertension, dtype: float64

# %%
sns.histplot(df['SystolicBP'])
plt.title("SystolicBP vs Diagnosis")
plt.show()
print(df['SystolicBP'].describe())
# Out:
# count    2149.000000
# mean      134.264774
# std        25.949352
# min        90.000000
# 25%       112.000000
# 50%       134.000000
# 75%       157.000000
# max       179.000000
# Name: SystolicBP, dtype: float64

# %%
sns.histplot(df['DiastolicBP'])
plt.title("DiastolicBP vs Diagnosis")
plt.show()
print(df['DiastolicBP'].describe())
# Out:
# count    2149.000000
# mean       89.847836
# std        17.592496
# min        60.000000
# 25%        74.000000
# 50%        91.000000
# 75%       105.000000
# max       119.000000
# Name: DiastolicBP, dtype: float64

# %%
sns.histplot(df['CholesterolTotal'])
plt.title("CholesterolTotal vs Diagnosis")
plt.show()
print(df['CholesterolTotal'].describe())
# Out:
# count    2149.000000
# mean      225.197519
# std        42.542233
# min       150.093316
# 25%       190.252963
# 50%       225.086430
# 75%       262.031657
# max       299.993352
# Name: CholesterolTotal, dtype: float64

# %%
sns.histplot(df['CholesterolLDL'])
plt.title("CholesterolLDL vs Diagnosis")
plt.show()
print(df['CholesterolLDL'].describe())
# Out:
# count    2149.000000
# mean      124.335944
# std        43.366584
# min        50.230707
# 25%        87.195798
# 50%       123.342593
# 75%       161.733733
# max       199.965665
# Name: CholesterolLDL, dtype: float64

# %%
sns.histplot(df['CholesterolHDL'])
plt.title("CholesterolHDL vs Diagnosis")
plt.show()
print(df['CholesterolHDL'].describe)
# Out:
# <bound method NDFrame.describe of 0       33.682563
# 1       79.028477
# 2       69.772292
# 3       68.457491
# 4       56.874305
#           ...
# 2144    60.943092
# 2145    93.649735
# 2146    99.678209
# 2147    81.281111
# 2148    81.920043
# Name: CholesterolHDL, Length: 2149, dtype: float64>

# %%
sns.histplot(df['CholesterolTriglycerides'])
plt.title("CholesterolTriglycerides vs Diagnosis")
plt.show()
print(df['CholesterolTriglycerides'].describe())
# Out:
# count    2149.000000
# mean      228.281496
# std       101.986721
# min        50.407194
# 25%       137.583222
# 50%       230.301983
# 75%       314.839046
# max       399.941862
# Name: CholesterolTriglycerides, dtype: float64

# %%
sns.histplot(df['MMSE'])
plt.title("MMSE vs Diagnosis")
plt.show()
print(df['MMSE'].describe())
# Out:
# count    2149.000000
# mean       14.755132
# std         8.613151
# min         0.005312
# 25%         7.167602
# 50%        14.441660
# 75%        22.161028
# max        29.991381
# Name: MMSE, dtype: float64

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
sns.histplot(df['FunctionalAssessment'])
plt.title("	FunctionalAssessment vs Diagnosis")
plt.show()
print(df['FunctionalAssessment'].describe())
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# count    2149.000000
# mean        5.080055
# std         2.892743
# min         0.000460
# 25%         2.566281
# 50%         5.094439
# 75%         7.546981
# max         9.996467
# Name: FunctionalAssessment, dtype: float64

# %%
sns.histplot(df['MemoryComplaints'])
plt.title("MemoryComplaints vs Diagnosis")
plt.show()
print(df['MemoryComplaints'].describe())
# Out:
# count    2149.000000
# mean        0.208004
# std         0.405974
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: MemoryComplaints, dtype: float64

# %%
sns.histplot(df['BehavioralProblems'])
plt.title("BehavioralProblems	 vs Diagnosis")
plt.show()
print(df['BehavioralProblems'].describe())
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# count    2149.000000
# mean        0.156817
# std         0.363713
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: BehavioralProblems, dtype: float64

# %%
sns.histplot(df['ADL'])
plt.title("ADL vs Diagnosis")
plt.show()
print(df['ADL'].describe())
# Out:
# count    2149.000000
# mean        4.982958
# std         2.949775
# min         0.001288
# 25%         2.342836
# 50%         5.038973
# 75%         7.581490
# max         9.999747
# Name: ADL, dtype: float64

# %%
sns.histplot(df['Confusion'])
plt.title("Confusion vs Diagnosis")
plt.show()
print(df['Confusion'].describe())
# Out:
# count    2149.000000
# mean        0.205212
# std         0.403950
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Confusion, dtype: float64

# %%
sns.histplot(df['Disorientation'])
plt.title("Disorientation	 vs Diagnosis")
plt.show()
print(df['Disorientation'].describe())
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# count    2149.000000
# mean        0.158213
# std         0.365026
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Disorientation, dtype: float64

# %%
sns.histplot(df['PersonalityChanges'])
plt.title("PersonalityChanges vs Diagnosis")
plt.show()
print(df['PersonalityChanges'].describe())
# Out:
# count    2149.000000
# mean        0.150768
# std         0.357906
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: PersonalityChanges, dtype: float64

# %%
sns.histplot(df['DifficultyCompletingTasks'])
plt.title("DifficultyCompletingTasks vs Diagnosis")
plt.show()
print(df['DifficultyCompletingTasks'].describe())
# Out:
# count    2149.000000
# mean        0.158678
# std         0.365461
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: DifficultyCompletingTasks, dtype: float64

# %%
sns.histplot(df['Forgetfulness'])
plt.title("Forgetfulness vs Diagnosis")
plt.show()
print(df['Forgetfulness'].describe())
# Out:
# count    2149.000000
# mean        0.301536
# std         0.459032
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Forgetfulness, dtype: float64

# %%
sns.histplot(df['Diagnosis'])
plt.title("Diagnosis vs Diagnosis")
plt.show()
print(df['Diagnosis'].describe())
# Out:
# count    2149.000000
# mean        0.353653
# std         0.478214
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Diagnosis, dtype: float64

# %% [markdown]
# UNIVARIATE CATEGORICAL

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df['Age'])
plt.xticks(rotation=40)
plt.title("Age count")
plt.show()

# %%
sns.countplot(x=df['Gender'])
plt.title("Gender count")
plt.show()
print(df["Gender"].describe())
# Out:
# count    2149.000000
# mean        0.506282
# std         0.500077
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Gender, dtype: float64

# %%
sns.countplot(x=df['Ethnicity'])
plt.title("Ethnicity count")
plt.show()
print(df["Ethnicity"].describe())
# Out:
# count    2149.000000
# mean        0.697534
# std         0.996128
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Ethnicity, dtype: float64

# %%
sns.countplot(x=df['EducationLevel'])
plt.title("EducationLevel count")
plt.show()
print(df["EducationLevel"].describe())
# Out:
# count    2149.000000
# mean        1.286645
# std         0.904527
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: EducationLevel, dtype: float64

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
sns.countplot(x=df['BMI'])
plt.title("BMI count")
plt.show()
print(df["BMI"].describe())
# Out:
# count    2149.000000
# mean       27.655697
# std         7.217438
# min        15.008851
# 25%        21.611408
# 50%        27.823924
# 75%        33.869778
# max        39.992767
# Name: BMI, dtype: float64

# %%
sns.countplot(x=df['Smoking'])
plt.title("Smoking count")
plt.show()
print(df["Smoking"].describe())
# Out:
# count    2149.000000
# mean        0.288506
# std         0.453173
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Smoking, dtype: float64

# %%
sns.countplot(x=df['AlcoholConsumption'])
plt.title("AlcoholConsumption count")
plt.show()
print(df["AlcoholConsumption"].describe())
# Out:
# count    2149.000000
# mean       10.039442
# std         5.757910
# min         0.002003
# 25%         5.139810
# 50%         9.934412
# 75%        15.157931
# max        19.989293
# Name: AlcoholConsumption, dtype: float64

# %%
sns.countplot(x=df['BMI'])
plt.title("BMI count")
plt.show()
print(df["BMI"].describe())
# Out:
# count    2149.000000
# mean       27.655697
# std         7.217438
# min        15.008851
# 25%        21.611408
# 50%        27.823924
# 75%        33.869778
# max        39.992767
# Name: BMI, dtype: float64

# %%
sns.countplot(x=df['Smoking'])
plt.title("Smoking count")
plt.show()
print(df["Smoking"].describe())
# Out:
# count    2149.000000
# mean        0.288506
# std         0.453173
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Smoking, dtype: float64

# %%
sns.kdeplot(x=df['AlcoholConsumption'])
plt.title("AlcoholConsumption count")
plt.show()
print(df["AlcoholConsumption"].describe())
# Out:
# count    2149.000000
# mean       10.039442
# std         5.757910
# min         0.002003
# 25%         5.139810
# 50%         9.934412
# 75%        15.157931
# max        19.989293
# Name: AlcoholConsumption, dtype: float64

# %%
sns.histplot(x=df['PhysicalActivity'])
plt.title("PhysicalActivity count")
plt.show()
print(df["PhysicalActivity"].describe())
# Out:
# count    2149.000000
# mean        4.920202
# std         2.857191
# min         0.003616
# 25%         2.570626
# 50%         4.766424
# 75%         7.427899
# max         9.987429
# Name: PhysicalActivity, dtype: float64

# %%
sns.histplot(x=df['SleepQuality'])
plt.title("SleepQuality count")
plt.show()
print(df["SleepQuality"].describe())
# Out:
# count    2149.000000
# mean        7.051081
# std         1.763573
# min         4.002629
# 25%         5.482997
# 50%         7.115646
# 75%         8.562521
# max         9.999840
# Name: SleepQuality, dtype: float64

# %%
df["DietQuality"].value_counts()
# Out:
# DietQuality
# 7.941404    1
# 1.347214    1
# 0.518767    1
# 1.826335    1
# 7.435604    1
#            ..
# 8.086019    1
# 6.736882    1
# 8.341903    1
# 5.897388    1
# 1.584922    1
# Name: count, Length: 2149, dtype: int64

# %%
sns.histplot(x=df['DietQuality'])
plt.title("DietQuality count")
plt.show()
print(df["DietQuality"].describe())
# Out:
# count    2149.000000
# mean        4.993138
# std         2.909055
# min         0.009385
# 25%         2.458455
# 50%         5.076087
# 75%         7.558625
# max         9.998346
# Name: DietQuality, dtype: float64

# %%
sns.histplot(x=df['FamilyHistoryAlzheimers'])
plt.title("FamilyHistoryAlzheimers count")
plt.show()
print(df["FamilyHistoryAlzheimers"].describe())
# Out:
# count    2149.000000
# mean        0.252210
# std         0.434382
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: FamilyHistoryAlzheimers, dtype: float64

# %%
sns.countplot(x=df['CardiovascularDisease'])
plt.title("CardiovascularDisease count")
plt.show()
print(df["CardiovascularDisease"].describe())
# Out:
# count    2149.000000
# mean        0.144253
# std         0.351428
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: CardiovascularDisease, dtype: float64

# %%
sns.countplot(x=df['Diabetes'])
plt.title("Diabetes count")
plt.show()
print(df["Diabetes"].describe())
# Out:
# count    2149.000000
# mean        0.150768
# std         0.357906
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Diabetes, dtype: float64

# %%
sns.countplot(x=df['Depression'])
plt.title("Depression count")
plt.show()
print(df["Depression"].describe())
# Out:
# count    2149.000000
# mean        0.200558
# std         0.400511
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Depression, dtype: float64

# %%
sns.countplot(x=df['HeadInjury'])
plt.title("HeadInjury count")
plt.show()
print(df["HeadInjury"].describe())
# Out:
# count    2149.000000
# mean        0.092601
# std         0.289940
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: HeadInjury, dtype: float64

# %%
sns.countplot(x=df['Hypertension'])
plt.title("Hypertension count")
plt.show()
print(df["Hypertension"].describe())
# Out:
# count    2149.000000
# mean        0.148906
# std         0.356079
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Hypertension, dtype: float64

# %%
sns.histplot(x=df['SystolicBP'])
plt.title("SystolicBP count")
plt.show()
print(df["SystolicBP"].describe())
# Out:
# count    2149.000000
# mean      134.264774
# std        25.949352
# min        90.000000
# 25%       112.000000
# 50%       134.000000
# 75%       157.000000
# max       179.000000
# Name: SystolicBP, dtype: float64

# %%
sns.histplot(x=df['DiastolicBP'])
plt.title("DiastolicBP count")
plt.show()
print(df["DiastolicBP"].describe())
# Out:
# count    2149.000000
# mean       89.847836
# std        17.592496
# min        60.000000
# 25%        74.000000
# 50%        91.000000
# 75%       105.000000
# max       119.000000
# Name: DiastolicBP, dtype: float64

# %%
sns.histplot(x=df['CholesterolTotal'])
plt.title("CholesterolTotal count")
plt.show()
print(df["CholesterolTotal"].describe())
# Out:
# count    2149.000000
# mean      225.197519
# std        42.542233
# min       150.093316
# 25%       190.252963
# 50%       225.086430
# 75%       262.031657
# max       299.993352
# Name: CholesterolTotal, dtype: float64

# %%
sns.histplot(x=df['CholesterolLDL'])
plt.title("CholesterolLDL count")
plt.show()
print(df["CholesterolLDL"].describe())
# Out:
# count    2149.000000
# mean      124.335944
# std        43.366584
# min        50.230707
# 25%        87.195798
# 50%       123.342593
# 75%       161.733733
# max       199.965665
# Name: CholesterolLDL, dtype: float64

# %%
sns.histplot(x=df['CholesterolHDL'])
plt.title("CholesterolHDL count")
plt.show()
print(df["CholesterolHDL"].describe())
# Out:
# count    2149.000000
# mean       59.463533
# std        23.139174
# min        20.003434
# 25%        39.095698
# 50%        59.768237
# 75%        78.939050
# max        99.980324
# Name: CholesterolHDL, dtype: float64

# %%
sns.histplot(x=df['CholesterolTriglycerides'])
plt.title("CholesterolTriglycerides count")
plt.show()
print(df["CholesterolTriglycerides"].describe())
# Out:
# count    2149.000000
# mean      228.281496
# std       101.986721
# min        50.407194
# 25%       137.583222
# 50%       230.301983
# 75%       314.839046
# max       399.941862
# Name: CholesterolTriglycerides, dtype: float64

# %%
sns.histplot(x=df['MMSE'])
plt.title("MMSE count")
plt.show()
print(df["MMSE"].describe())
# Out:
# count    2149.000000
# mean       14.755132
# std         8.613151
# min         0.005312
# 25%         7.167602
# 50%        14.441660
# 75%        22.161028
# max        29.991381
# Name: MMSE, dtype: float64

# %%
sns.histplot(x=df['FunctionalAssessment'])
plt.title("FunctionalAssessment count")
plt.show()
print(df["FunctionalAssessment"].describe())
# Out:
# count    2149.000000
# mean        5.080055
# std         2.892743
# min         0.000460
# 25%         2.566281
# 50%         5.094439
# 75%         7.546981
# max         9.996467
# Name: FunctionalAssessment, dtype: float64

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
sns.countplot(x=df['MemoryComplaints'])
plt.title("MemoryComplaints count")
plt.show()
print(df["MemoryComplaints"].describe())
# Out:
# count    2149.000000
# mean        0.208004
# std         0.405974
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: MemoryComplaints, dtype: float64

# %%
sns.countplot(x=df['BehavioralProblems'])
plt.title("BehavioralProblems	count")
plt.show()
print(df["BehavioralProblems"].describe())
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# count    2149.000000
# mean        0.156817
# std         0.363713
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: BehavioralProblems, dtype: float64

# %%
sns.histplot(x=df['ADL'])
plt.title("ADL count")
plt.show()
print(df["ADL"].describe())
# Out:
# count    2149.000000
# mean        4.982958
# std         2.949775
# min         0.001288
# 25%         2.342836
# 50%         5.038973
# 75%         7.581490
# max         9.999747
# Name: ADL, dtype: float64

# %%
sns.countplot(x=df['Confusion'])
plt.title("Confusion count")
plt.show()
print(df["Confusion"].describe())
# Out:
# count    2149.000000
# mean        0.205212
# std         0.403950
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Confusion, dtype: float64

# %%
sns.countplot(x=df['Disorientation'])
plt.title("Disorientation	count")
plt.show()
print(df["Disorientation"].describe())
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# count    2149.000000
# mean        0.158213
# std         0.365026
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Disorientation, dtype: float64

# %%
sns.countplot(x=df['PersonalityChanges'])
plt.title("PersonalityChanges count")
plt.show()
print(df["PersonalityChanges"].describe())
# Out:
# count    2149.000000
# mean        0.150768
# std         0.357906
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: PersonalityChanges, dtype: float64

# %%
sns.countplot(x=df['DifficultyCompletingTasks'])
plt.title("DifficultyCompletingTasks count")
plt.show()
print(df["DifficultyCompletingTasks"].describe())
# Out:
# count    2149.000000
# mean        0.158678
# std         0.365461
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: DifficultyCompletingTasks, dtype: float64

# %%
sns.countplot(x=df['Forgetfulness'])
plt.title("Forgetfulness count")
plt.show()
print(df["Forgetfulness"].describe())
# Out:
# count    2149.000000
# mean        0.301536
# std         0.459032
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Forgetfulness, dtype: float64

# %%
sns.countplot(x=df['Diagnosis'])
plt.title("Diagnosis count")
plt.show()
print(df["Diagnosis"].describe())
# Out:
# count    2149.000000
# mean        0.353653
# std         0.478214
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Diagnosis, dtype: float64

# %%
sns.boxplot(y=df['Age'])
plt.title('Age')
plt.show()

# %%
sns.boxplot(y=df['BMI'])
plt.title('BMI')
plt.show()

# %%
sns.boxplot(y=df['AlcoholConsumption'])
plt.title('AlcoholConsumption')
plt.show()

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0      73       0          0               2  22.927749        0
# 1      89       0          0               0  26.827681        0
# 2      73       0          3               1  17.795882        0
# 3      74       1          0               1  33.800817        1
# 4      89       0          0               0  20.716974        0
# ...   ...     ...        ...             ...        ...      ...
# 2144   61       0          0               1  39.121757        0
# 2145   75       0          0               2  17.857903        0
# 2146   77       0          0               1  15.476479        0
# 2147   78       1          3               1  15.299911        0
# 2148   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0              13.297218          6.327112     1.347214      9.025679
# ...

# %%
sns.boxplot(y=df['PhysicalActivity'])
plt.title('PhysicalActivity')
plt.show()

# %%
sns.boxplot(y=df['DietQuality'])
plt.title('DietQuality')
plt.show()

# %%
sns.boxplot(y=df['SleepQuality'])
plt.title('SleepQuality')
plt.show()

# %%
sns.boxplot(y=df['SystolicBP'])
plt.title('SystolicBP')
plt.show()

# %%
sns.boxplot(y=df['DiastolicBP'])
plt.title('DiastolicBP')
plt.show()

# %%
sns.boxplot(y=df['CholesterolTotal'])
plt.title('CholesterolTotal')
plt.show()

# %%
sns.boxplot(y=df['CholesterolLDL'])
plt.title('CholesterolLDL')
plt.show()

# %%
sns.boxplot(y=df['CholesterolHDL'])
plt.title('CholesterolHDL')
plt.show()

# %%
sns.boxplot(y=df['CholesterolTriglycerides'])
plt.title('CholesterolTriglycerides')
plt.show()

# %%
sns.boxplot(y=df['MMSE'])
plt.title('MMSE')
plt.show()

# %%
sns.boxplot(y=df['FunctionalAssessment'])
plt.title('FunctionalAssessment')
plt.show()

# %%
sns.boxplot(y=df['ADL'])
plt.title('ADL')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(40,20))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm",linewidths=0.5)
plt.title("correlation Heatmap")
plt.show()

# %%
df=df[["SleepQuality","MMSE","FunctionalAssessment","MemoryComplaints","BehavioralProblems","ADL"]]

# %%
df
# Out:
#       SleepQuality       MMSE  FunctionalAssessment  MemoryComplaints  \
# 0         9.025679  21.463532              6.518877                 0
# 1         7.151293  20.613267              7.118696                 0
# 2         9.673574   7.356249              5.895077                 0
# 3         8.392554  13.991127              8.965106                 0
# 4         5.597238  13.517609              6.045039                 0
# ...            ...        ...                   ...               ...
# 2144      7.535540   1.201190              0.238667                 0
# 2145      8.555256   6.458060              8.687480                 0
# 2146      5.769464  17.011003              1.972137                 0
# 2147      8.322874   4.030491              5.173891                 0
# 2148      9.878711  11.114777              6.307543                 0
#
#       BehavioralProblems       ADL
# 0                      0  1.725883
# 1                      0  2.592424
# ...
